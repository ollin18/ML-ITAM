# %%
import numpy as np
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn import linear_model
from scipy.stats import *

from bokeh.plotting import figure
from bokeh.io import output_notebook, show#, output_file #Descomentar para guardar el archivo .html
from bokeh.models.widgets import Panel, Tabs
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d00410d7-acc1-45cc-8dd1-3c0299f759a9">Loading BokehJS ...</span>
#     </div>

# %%
def sets(data_frame):
    entrenamiento, prueba = train_test_split(data_frame, test_size=0.2, random_state=18)
    return entrenamiento, prueba

def cuadratica(x,n=None):
    return 0.6*x**2+(1.6*x)

def la_funcion(f, data_frame,n=None):    
    aplicada = f(data_frame,n)
    return aplicada

def la_regresion(f, data_frame,n=None):
    entrenamiento, prueba = sets(data_frame)
    regresion = linear_model.LinearRegression()
    return regresion.fit(la_funcion(f, entrenamiento.X.reshape(-1, 1),n), entrenamiento.y)

def los_errores(f, data_frame,n=None):
    entrenamiento, prueba = sets(data_frame)
    regresion = la_regresion(f, data_frame,n)
    las_buenas = entrenamiento.y
    errores = []
    for i in np.arange(-10,10,0.1):
        las_predichas = (regresion.predict(entrenamiento.X.reshape(-1,1))+i)
        las_predichas = la_funcion(f,las_predichas,n)
        errores.append(sum((las_buenas-las_predichas)**2)/len(las_buenas))
    return errores

def la_grafica(f, data_frame,n=None):
    entrenamiento, prueba = sets(data_frame)
    regresion = la_regresion(f, data_frame,n)
    errores = los_errores(f, data_frame,n)
    
    s1 = figure(width=750, plot_height=500, title=None)
    s1.circle(entrenamiento.X,entrenamiento.y, size=5, color="red", alpha=0.5)
    s1.line(entrenamiento.sort_values(by='X').X, la_funcion(f, regresion.predict(entrenamiento.sort_values(by='X').X.reshape(-1,1)),n), line_width=1.5, color="navy", alpha=0.7)
    s1.title.text = "Regresión de entrenamiento"
    s1.xaxis.axis_label = "X"
    s1.yaxis.axis_label = "y"
    tab1 = Panel(child=s1, title="Entrenamiento")
    
    s2 = figure(width=750, plot_height=500, title=None)
    s2.circle(prueba.X,prueba.y, size=5, color="red", alpha=0.5)
    s2.line(prueba.sort_values(by='X').X, la_funcion(f, regresion.predict(prueba.sort_values(by='X').X.reshape(-1,1)),n), line_width=1.5, color="navy", alpha=0.7)
    s2.title.text = "Regresión con la prueba"
    s2.xaxis.axis_label = "X"
    s2.yaxis.axis_label = "y"
    tab2 = Panel(child=s2, title="Prueba")
    
    s3 = figure(width=750, plot_height=500, title=None)
    s3.circle(np.arange(-10,10,0.1)+regresion.intercept_,errores, size=5, color="red", alpha=0.5)
    s3.circle(regresion.intercept_,sum(((la_funcion(f,regresion.coef_*entrenamiento.X,n)+la_funcion(f,regresion.intercept_,n)-entrenamiento.y)**2))/len(entrenamiento.X),size=8,color="navy",alpha=0.6)
    s3.title.text = "Errores"
    s3.xaxis.axis_label = "X"
    s3.yaxis.axis_label = "y"
    tab3 = Panel(child=s3, title="Errores")
    
    tabs = Tabs(tabs=[ tab1, tab2, tab3])

    show(tabs)
    
    #print('Score de varianza: \n{}\n').format(score_varianza)

    #print('Suma del cuadrado de los residuos: \n{}\n').format(suma_cuadrados)

    #print('Coeficiente: \n{}\n').format(coeficiente)
    
    print('Ordenada: \n{}\n').format(regresion.intercept_)
    
    print('Pendiente: \n{}\n').format(regresion.coef_[0])

# %%
df0 = pd.read_csv("regLin.csv")
df1 = pd.read_csv("regLin2.csv")
df2 = pd.read_csv("regLin3.csv")

# %%
la_grafica(pow,df0,1)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="
","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"3cae5391-49ae-42c6-abd3-2b5342ed88d2","subtype":"Figure","type":"Plot"}},"id":"19484a66-b989-4011-9cc4-fda85e306720","type":"WheelZoomTool"},{"attributes":{},"id":"4dd3ca5d-9cd2-444c-b1d1-1c7a48cf2102","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c2729eef-a5ca-4545-bbd2-b756e5c25f07","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"00daf2bc-a05b-413c-bf7b-5d358c77af37","subtype":"Figure","type":"Plot"}},"id":"fb9bc542-ce01-4c56-970a-2cc8193cb709","type":"ResetTool"},{"attributes":{"plot":{"id":"00daf2bc-a05b-413c-bf7b-5d358c77af37","subtype":"Figure","type":"Plot"}},"id":"4b2bc5f0-e7c2-4688-94a4-8966d0b18a3c","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"3cae5391-49ae-42c6-abd3-2b5342ed88d2","subtype":"Figure","type":"Plot"},"ticker":{"id":"dc1940d0-53c7-48a9-b661-c7d2e7035e62","type":"BasicTicker"}},"id":"a5bb5b03-eb35-4330-8a37-35d378044e11","type":"Grid"},{"attributes":{},"id":"48d9a8df-15ac-47f3-804a-0016550d0fe9","type":"BasicTickFormatter"},{"attributes":{},"id":"ca2aba0d-b9c1-496d-8281-b6927add0ede","type":"ToolEvents"},{"attributes":{"axis_label":"y","formatter":{"id":"448e070b-b280-4853-884b-519e02e06509","type":"BasicTickFormatter"},"plot":{"id":"00daf2bc-a05b-413c-bf7b-5d358c77af37","subtype":"Figure","type":"Plot"},"ticker":{"id":"0fc42d14-f462-4d13-aee1-b98addbf4284","type":"BasicTicker"}},"id":"941cbcdb-63b3-41f7-805a-9e23494d3df9","type":"LinearAxis"},{"attributes":{"plot":null,"text":"Regresi\u00f3n de entrenamiento"},"id":"77765c40-1eb9-4127-911f-34114ecb5cae","type":"Title"},{"attributes":{"axis_label":"y","formatter":{"id":"3f0bb0dc-5f75-4f76-9b38-f5260b373f05","type":"BasicTickFormatter"},"plot":{"id":"3cae5391-49ae-42c6-abd3-2b5342ed88d2","subtype":"Figure","type":"Plot"},"ticker":{"id":"4dd3ca5d-9cd2-444c-b1d1-1c7a48cf2102","type":"BasicTicker"}},"id":"aa5f879a-409d-4a6f-8182-47f91be6adf5","type":"LinearAxis"},{"attributes":{"plot":{"id":"3cae5391-49ae-42c6-abd3-2b5342ed88d2","subtype":"Figure","type":"Plot"}},"id":"09ac372c-9c21-4113-b6c6-1ec09905b691","type":"HelpTool"},{"attributes":{"plot":{"id":"04a90e63-a30c-4e8f-b333-bd6bd28f06a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"7dc068a9-16ec-4ebb-b1d9-29bb2e33e352","type":"BasicTicker"}},"id":"fffba258-cd5d-4e13-8722-d68f0dabf1b9","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"39b63f85-fea3-4d54-b1e3-ca00b175bdbc","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"red"},"line_alpha":{"value":0.5},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"c33d98a7-64c5-47ba-9c6c-65138a70b9f8","type":"Circle"},{"attributes":{"overlay":{"id":"c2729eef-a5ca-4545-bbd2-b756e5c25f07","type":"BoxAnnotation"},"plot":{"id":"3cae5391-49ae-42c6-abd3-2b5342ed88d2","subtype":"Figure","type":"Plot"}},"id":"4f95da57-0ba0-41cd-af90-f915d4193e78","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"red"},"line_alpha":{"value":0.5},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"b2f2895e-1dd1-4d66-b616-5df8744aa4b4","type":"Circle"},{"attributes":{},"id":"c6c2a548-1d69-4006-987b-d62418fa2218","type":"ToolEvents"},{"attributes":{},"id":"e498dca4-1ec0-4bc5-a687-06d67bc2f4c4","type":"BasicTic ...
# Ordenada:
# 6.67873291393e-11
#
# Pendiente:
# 1.00000000003
